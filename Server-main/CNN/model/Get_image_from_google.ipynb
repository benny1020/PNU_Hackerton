# %%
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
import time
import urllib.request

# %%
driver = webdriver.Chrome('/Users/roopre/Desktop/chromedriver') # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://www.google.co.kr/imghp?hl=ko")
elem = driver.find_element_by_name("q")
elem.send_keys("flying birds")
elem.send_keys(Keys.RETURN)

# %%
num = 10
count = 0
SCROLL_PAUSE_TIME = 0.5
 
last_height = driver.execute_script("return document.body.scrollHeight")
 
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
 
    time.sleep(SCROLL_PAUSE_TIME)
 
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_height = new_height

images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
for image in images:

    try:
        image.click()  
        time.sleep(1)

        imgURL=driver.find_element_by_xpath("/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div[1]/div[1]/div/div[2]/a/img").get_attribute("src")
        print(imgURL)
        urllib.request.urlretrieve(imgURL , str(search) + str(count) + ".jpg")

        count = count + 1

    except:

        pass

    if count == int(num)+1:

        break

# %%
driver.close()

# %%
SCROLL_PAUSE_TIME = 0.5
 
last_height = driver.execute_script("return document.body.scrollHeight")
 
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
 
    time.sleep(SCROLL_PAUSE_TIME)
 
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_height = new_height

images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
count = 1
for image in images:
    try: 
        image.click()
        time.sleep(1)
        imgUrl = driver.find_element_by_xpath('/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div/div[2]/a/img').get_attribute("src")
        print(imgUrl)
        urllib.request.urlretrieve(imgUrl, str(count) + ".jpg")
        count = count + 1
    except:
        pass
    
driver.close()

# %%
count
# Out:
# 1

# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys 
import time 
import os 
import urllib.request

# %%
def createFolder(directory): 
    try: 
        if not os.path.exists(directory): 
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' + directory)

# %%
def get_image_google(keyword,num):
    #keyword='김치볶음밥 사진' 
    createFolder('./'+keyword) 
    chromedriver = '/Users/roopre/Desktop/chromedriver' 
    driver = webdriver.Chrome(chromedriver)
    driver.implicitly_wait(3)
    print(keyword, '검색') 
    driver.get('https://www.google.co.kr/imghp?hl=ko') 
    Keyword=driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input') 
    Keyword.send_keys(keyword) 
    driver.find_element_by_xpath('//*[@id="sbtc"]/button').click()
    print(keyword+' 스크롤 중 .............') 
    elem = driver.find_element_by_tag_name("body") 
    for i in range(120): 
        elem.send_keys(Keys.PAGE_DOWN) 
        time.sleep(0.5) 
    try: 
        driver.find_element_by_xpath('//*[@id="islmp"]/div/div/div/div[1]/div[4]/div[2]/input').click() 
        for i in range(120): 
            elem.send_keys(Keys.PAGE_DOWN) 
            time.sleep(0.5) 
    except: 
        pass
    links=[] 
    images = driver.find_elements_by_css_selector("img.rg_i.Q4LuWd") 
    for image in images: 
        if image.get_attribute('src')!=None: 
            links.append(image.get_attribute('src')) 
            if len(links)==num:
                break
    print(keyword+' 찾은 이미지 개수:',len(links)) 
    time.sleep(2)
    for k,i in enumerate(links): 
        url = i 
        start = time.time() 
        urllib.request.urlretrieve(url, "./"+keyword+"/"+keyword+"_"+str(k)+".jpg") 
        print(str(k+1)+'/'+str(len(links))+' '+keyword+' 다운로드 중....... Download time : '+str(time.time() - start)[:5]+' 초') 
        print(keyword+' ---다운로드 완료---') 
    
    driver.close()

# %%
get_image_google("김치볶음밥 사진",100)
# Out:
# 김치볶음밥 사진 검색
# 김치볶음밥 사진 스크롤 중 .............
# 쌀밥 사진 검색
# 쌀밥 사진 스크롤 중 .............
# 쌀밥 사진 찾은 이미지 개수: 100
# 1/100 쌀밥 사진 다운로드 중....... Download time : 0.001 초
# 쌀밥 사진 ---다운로드 완료---
# 2/100 쌀밥 사진 다운로드 중....... Download time : 0.001 초
# 쌀밥 사진 ---다운로드 완료---
# 3/100 쌀밥 사진 다운로드 중....... Download time : 0.001 초
# 쌀밥 사진 ---다운로드 완료---
# 4/100 쌀밥 사진 다운로드 중....... Download time : 0.000 초
# 쌀밥 사진 ---다운로드 완료---
# 5/100 쌀밥 사진 다운로드 중....... Download time : 0.000 초
# 쌀밥 사진 ---다운로드 완료---
# 6/100 쌀밥 사진 다운로드 중....... Download time : 0.001 초
# 쌀밥 사진 ---다운로드 완료---
# 7/100 쌀밥 사진 다운로드 중....... Download time : 0.000 초
# 쌀밥 사진 ---다운로드 완료---
# 8/100 쌀밥 사진 다운로드 중....... Download time : 0.000 초
# 쌀밥 사진 ---다운로드 완료---
# 9/100 쌀밥 사진 다운로드 중....... Download time : 0.000 초
# 쌀밥 사진 ---다운로드 완료---
# 10/100 쌀밥 사진 다운로드 중....... Download time : 0.000 초
# 쌀밥 사진 ---다운로드 완료---
# 11/100 쌀밥 사진 다운로드 중....... Download time : 0.000 초
# 쌀밥 사진 ---다운로드 완료---
# 12/100 쌀밥 사진 다운로드 중....... Download time : 0.000 초
# 쌀밥 사진 ---다운로드 완료---
# ...

# %%
get_image_google("토스트 사진",100)
# Out:
# 토스트 사진 검색
# 토스트 사진 스크롤 중 .............
# 토스트 사진 찾은 이미지 개수: 100
# 1/100 토스트 사진 다운로드 중....... Download time : 0.001 초
# 토스트 사진 ---다운로드 완료---
# 2/100 토스트 사진 다운로드 중....... Download time : 0.001 초
# 토스트 사진 ---다운로드 완료---
# 3/100 토스트 사진 다운로드 중....... Download time : 0.001 초
# 토스트 사진 ---다운로드 완료---
# 4/100 토스트 사진 다운로드 중....... Download time : 0.001 초
# 토스트 사진 ---다운로드 완료---
# 5/100 토스트 사진 다운로드 중....... Download time : 0.001 초
# 토스트 사진 ---다운로드 완료---
# 6/100 토스트 사진 다운로드 중....... Download time : 0.000 초
# 토스트 사진 ---다운로드 완료---
# 7/100 토스트 사진 다운로드 중....... Download time : 0.000 초
# 토스트 사진 ---다운로드 완료---
# 8/100 토스트 사진 다운로드 중....... Download time : 0.000 초
# 토스트 사진 ---다운로드 완료---
# 9/100 토스트 사진 다운로드 중....... Download time : 0.000 초
# 토스트 사진 ---다운로드 완료---
# 10/100 토스트 사진 다운로드 중....... Download time : 0.001 초
# 토스트 사진 ---다운로드 완료---
# 11/100 토스트 사진 다운로드 중....... Download time : 0.000 초
# 토스트 사진 ---다운로드 완료---
# 12/100 토스트 사진 다운로드 중....... Download time : 0.000 초
# 토스트 사진 ---다운로드 완료---
# ...

# %%
get_image_google("샐러드 사진",100)
# Out:
# 1/100 카레 사진 다운로드 중....... Download time : 0.001 초
# 카레 사진 ---다운로드 완료---
# 2/100 카레 사진 다운로드 중....... Download time : 0.001 초
# 카레 사진 ---다운로드 완료---
# 3/100 카레 사진 다운로드 중....... Download time : 0.001 초
# 카레 사진 ---다운로드 완료---
# 4/100 카레 사진 다운로드 중....... Download time : 0.000 초
# 카레 사진 ---다운로드 완료---
# 5/100 카레 사진 다운로드 중....... Download time : 0.001 초
# 카레 사진 ---다운로드 완료---
# 6/100 카레 사진 다운로드 중....... Download time : 0.000 초
# 카레 사진 ---다운로드 완료---
# 7/100 카레 사진 다운로드 중....... Download time : 0.000 초
# 카레 사진 ---다운로드 완료---
# 8/100 카레 사진 다운로드 중....... Download time : 0.000 초
# 카레 사진 ---다운로드 완료---
# 9/100 카레 사진 다운로드 중....... Download time : 0.001 초
# 카레 사진 ---다운로드 완료---
# 10/100 카레 사진 다운로드 중....... Download time : 0.000 초
# 카레 사진 ---다운로드 완료---
# 11/100 카레 사진 다운로드 중....... Download time : 0.001 초
# 카레 사진 ---다운로드 완료---
# 12/100 카레 사진 다운로드 중....... Download time : 0.001 초
# 카레 사진 ---다운로드 완료---
# ...

# %%
get_image_google("짜장면 사진",100)
# Out:
# 짜장면 사진 검색
# 짜장면 사진 스크롤 중 .............
# 짜장면 사진 찾은 이미지 개수: 100
# 1/100 짜장면 사진 다운로드 중....... Download time : 0.001 초
# 짜장면 사진 ---다운로드 완료---
# 2/100 짜장면 사진 다운로드 중....... Download time : 0.001 초
# 짜장면 사진 ---다운로드 완료---
# 3/100 짜장면 사진 다운로드 중....... Download time : 0.001 초
# 짜장면 사진 ---다운로드 완료---
# 4/100 짜장면 사진 다운로드 중....... Download time : 0.001 초
# 짜장면 사진 ---다운로드 완료---
# 5/100 짜장면 사진 다운로드 중....... Download time : 0.001 초
# 짜장면 사진 ---다운로드 완료---
# 6/100 짜장면 사진 다운로드 중....... Download time : 0.001 초
# 짜장면 사진 ---다운로드 완료---
# 7/100 짜장면 사진 다운로드 중....... Download time : 0.000 초
# 짜장면 사진 ---다운로드 완료---
# 8/100 짜장면 사진 다운로드 중....... Download time : 0.000 초
# 짜장면 사진 ---다운로드 완료---
# 9/100 짜장면 사진 다운로드 중....... Download time : 0.001 초
# 짜장면 사진 ---다운로드 완료---
# 10/100 짜장면 사진 다운로드 중....... Download time : 0.000 초
# 짜장면 사진 ---다운로드 완료---
# 11/100 짜장면 사진 다운로드 중....... Download time : 0.001 초
# 짜장면 사진 ---다운로드 완료---
# 12/100 짜장면 사진 다운로드 중....... Download time : 0.000 초
# 짜장면 사진 ---다운로드 완료---
# ...

# %%
get_image_google("탕수육 사진",100)
# Out:
# 탕수육 사진 검색
# 탕수육 사진 스크롤 중 .............
# 탕수육 사진 찾은 이미지 개수: 100
# 1/100 탕수육 사진 다운로드 중....... Download time : 0.001 초
# 탕수육 사진 ---다운로드 완료---
# 2/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# 3/100 탕수육 사진 다운로드 중....... Download time : 0.001 초
# 탕수육 사진 ---다운로드 완료---
# 4/100 탕수육 사진 다운로드 중....... Download time : 0.001 초
# 탕수육 사진 ---다운로드 완료---
# 5/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# 6/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# 7/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# 8/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# 9/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# 10/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# 11/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# 12/100 탕수육 사진 다운로드 중....... Download time : 0.000 초
# 탕수육 사진 ---다운로드 완료---
# ...

# %%
get_image_google("양념치킨 사진",100)
# Out:
# 양념치킨 사진 검색
# 양념치킨 사진 스크롤 중 .............
# 양념치킨 사진 찾은 이미지 개수: 100
# 1/100 양념치킨 사진 다운로드 중....... Download time : 0.002 초
# 양념치킨 사진 ---다운로드 완료---
# 2/100 양념치킨 사진 다운로드 중....... Download time : 0.002 초
# 양념치킨 사진 ---다운로드 완료---
# 3/100 양념치킨 사진 다운로드 중....... Download time : 0.002 초
# 양념치킨 사진 ---다운로드 완료---
# 4/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# 양념치킨 사진 ---다운로드 완료---
# 5/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# 양념치킨 사진 ---다운로드 완료---
# 6/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# 양념치킨 사진 ---다운로드 완료---
# 7/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# 양념치킨 사진 ---다운로드 완료---
# 8/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# 양념치킨 사진 ---다운로드 완료---
# 9/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# 양념치킨 사진 ---다운로드 완료---
# 10/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# 양념치킨 사진 ---다운로드 완료---
# 11/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# 양념치킨 사진 ---다운로드 완료---
# 12/100 양념치킨 사진 다운로드 중....... Download time : 0.001 초
# ...

# %%
get_image_google("후라이드치킨 사진",100)
# Out:
# 후라이드치킨 사진 검색
# 후라이드치킨 사진 스크롤 중 .............
# 후라이드치킨 사진 찾은 이미지 개수: 100
# 1/100 후라이드치킨 사진 다운로드 중....... Download time : 0.001 초
# 후라이드치킨 사진 ---다운로드 완료---
# 2/100 후라이드치킨 사진 다운로드 중....... Download time : 0.001 초
# 후라이드치킨 사진 ---다운로드 완료---
# 3/100 후라이드치킨 사진 다운로드 중....... Download time : 0.001 초
# 후라이드치킨 사진 ---다운로드 완료---
# 4/100 후라이드치킨 사진 다운로드 중....... Download time : 0.001 초
# 후라이드치킨 사진 ---다운로드 완료---
# 5/100 후라이드치킨 사진 다운로드 중....... Download time : 0.000 초
# 후라이드치킨 사진 ---다운로드 완료---
# 6/100 후라이드치킨 사진 다운로드 중....... Download time : 0.000 초
# 후라이드치킨 사진 ---다운로드 완료---
# 7/100 후라이드치킨 사진 다운로드 중....... Download time : 0.000 초
# 후라이드치킨 사진 ---다운로드 완료---
# 8/100 후라이드치킨 사진 다운로드 중....... Download time : 0.000 초
# 후라이드치킨 사진 ---다운로드 완료---
# 9/100 후라이드치킨 사진 다운로드 중....... Download time : 0.001 초
# 후라이드치킨 사진 ---다운로드 완료---
# 10/100 후라이드치킨 사진 다운로드 중....... Download time : 0.000 초
# 후라이드치킨 사진 ---다운로드 완료---
# 11/100 후라이드치킨 사진 다운로드 중....... Download time : 0.001 초
# 후라이드치킨 사진 ---다운로드 완료---
# ...

# %%
get_image_google("pizza image",100)
# Out:
# pizza image 검색
# pizza image 스크롤 중 .............
# pizza image 찾은 이미지 개수: 100
# 1/100 pizza image 다운로드 중....... Download time : 0.001 초
# pizza image ---다운로드 완료---
# 2/100 pizza image 다운로드 중....... Download time : 0.002 초
# pizza image ---다운로드 완료---
# 3/100 pizza image 다운로드 중....... Download time : 0.001 초
# pizza image ---다운로드 완료---
# 4/100 pizza image 다운로드 중....... Download time : 0.001 초
# pizza image ---다운로드 완료---
# 5/100 pizza image 다운로드 중....... Download time : 0.001 초
# pizza image ---다운로드 완료---
# 6/100 pizza image 다운로드 중....... Download time : 0.000 초
# pizza image ---다운로드 완료---
# 7/100 pizza image 다운로드 중....... Download time : 0.001 초
# pizza image ---다운로드 완료---
# 8/100 pizza image 다운로드 중....... Download time : 0.001 초
# pizza image ---다운로드 완료---
# 9/100 pizza image 다운로드 중....... Download time : 0.001 초
# pizza image ---다운로드 완료---
# 10/100 pizza image 다운로드 중....... Download time : 0.001 초
# pizza image ---다운로드 완료---
# 11/100 pizza image 다운로드 중....... Download time : 0.001 초
# ...

# %%
get_image_google("잔치국수 사진",100)
# Out:
# 잔치국수 사진 검색
# 잔치국수 사진 스크롤 중 .............
# 잔치국수 사진 찾은 이미지 개수: 100
# 1/100 잔치국수 사진 다운로드 중....... Download time : 0.001 초
# 잔치국수 사진 ---다운로드 완료---
# 2/100 잔치국수 사진 다운로드 중....... Download time : 0.001 초
# 잔치국수 사진 ---다운로드 완료---
# 3/100 잔치국수 사진 다운로드 중....... Download time : 0.000 초
# 잔치국수 사진 ---다운로드 완료---
